# %% [markdown]
# 1 MODEL (1 train)
#
# ResNet50
#
# cropped image around face
#
# The length of Train set is 2494 -> batch_size=16 ---
# The length of Valid set is 293 -> batch_size=8
#
# The length of Test set is 243 (personi 0-3 meters distance to camera)
#
# lr=0.001 ---
# num_epochs = 50
#
# ![Soluzione_ResNet50.png](data:image/png;base64,...)
#
# Epoch: 1  Train Loss: 0.0664  Valid Loss: 0.0224
#
# Epoch: 50  Train Loss: 0.0162  Valid Loss: 0.0149
#
# ![Screenshot from 2022-09-01 11-09-14.png](data:image/png;base64,...)

# %% [markdown]
# 1 MODEL (2 train)
#
# ResNet50
#
# NO cropped image
#
# The length of Train set is 4318 -> batch_size=32 --- The length of Valid set is 508 -> batch_size=16
#
# The length of Test set is 243 (personi 0-3 meters distance to camera)
#
# lr=0.001 --- num_epochs = 30
#
# ![Soluzione_resnet50_noCrop.png](data:image/png;base64,...)
#
# Epoch: 1  Train Loss: 0.0727  Valid Loss: 0.0702
#
# Epoch: 30  Train Loss: 0.0012  Valid Loss: 0.0049
#
# ![Screenshot from 2022-09-01 11-19-17.png](data:image/png;base64,...)

# %% [markdown]
# 1 MODEL (3 train)
#
# ResNet50
#
# NO cropped image --- image turn of 90 degrees
#
# The length of Train set is 4318 -> batch_size=64 --- The length of Valid set is 508 -> batch_size=32
#
# The length of Test set is 243 (personi 0-3 meters distance to camera)
#
# lr=0.0001 --- num_epochs = 30
#
# ![Soluzione_resnet50_noCrop_secondoGiro_imgRuotate90.png](data:image/png;base64,...)
#
# Epoch: 1  Train Loss: 0.0119  Valid Loss: 0.0082
#
# Epoch: 30  Train Loss: 0.0025  Valid Loss: 0.0027
#
# ![Screenshot from 2022-09-01 11-22-02.png](data:image/png;base64,...)

# %% [markdown]
# 1 MODEL (4 train)
#
# ResNet50
#
# NO cropped image --- change the size of images
#
# The length of Train set is 974 -> batch_size=16 --- The length of Valid set is 117 -> batch_size=8
#
# The length of Test set is 243 (personi 0-3 meters distance to camera)
#
# lr=0.0001 --- num_epochs = 50
#
# ![Soluzione_resnext50_noCrop_terzoGiro_screen.png](data:image/png;base64,...)
#
# Epoch: 1  Train Loss: 0.0040  Valid Loss: 0.1977
#
# Epoch: 50  Train Loss: 0.0005  Valid Loss: 0.0252
#
# ![Screenshot from 2022-09-01 11-25-21.png](data:image/png;base64,...)

# %% [markdown]
# ####################
#
#
# ####################
#
#
# ####################

# %% [markdown]
# 1 MODEL (1 train)
#
# ResNext50
#
# NO cropped image
#
# The length of Train set is 4318 -> batch_size=32 --- The length of Valid set is 508 -> batch_size=16
#
# The length of Test set is 243 (personi 0-3 meters distance to camera)
#
# lr=0.001 --- num_epochs = 30
#
# ![Soluzione_resnext50_noCrop.png](data:image/png;base64,...)
#
# Epoch: 1  Train Loss: 0.0697  Valid Loss: 0.0144
#
# Epoch: 30  Train Loss: 0.0017  Valid Loss: 0.0030
#
# ![Screenshot from 2022-09-01 11-28-58.png](data:image/png;base64,...)

# %% [markdown]
# 2 MODEL (2 train)
#
# ResNext50
#
# NO cropped image --- image turn of 90 degrees
#
# The length of Train set is 4318 -> batch_size=64 --- The length of Valid set is 508 -> batch_size=32
#
# The length of Test set is 243 (personi 0-3 meters distance to camera)
#
# lr=0.0001 --- num_epochs = 30
#
# ![Soluzione_resnext50_noCrop_secondoGiro_90gradi.png](data:image/png;base64,...)
#
# Epoch: 1  Train Loss: 0.0104  Valid Loss: 0.0077
#
# Epoch: 30  Train Loss: 0.0022  Valid Loss: 0.0033
#
# ![Screenshot from 2022-09-01 11-31-27.png](data:image/png;base64,...)

# %% [markdown]
# 2 MODEL (3 train)
#
# ResNext50
#
# NO cropped image --- change the size of images
#
# The length of Train set is 974 -> batch_size=16 --- The length of Valid set is 117 -> batch_size=8
#
# The length of Test set is 243 (personi 0-3 meters distance to camera)
#
# lr=0.0001 --- num_epochs = 50
#
# ![Soluzione_resnext50_noCrop_terzoGiro_screen.png](data:image/png;base64,...)
#
# Epoch: 1  Train Loss: 0.0030  Valid Loss: 0.0030
#
# Epoch: 50  Train Loss: 0.0003  Valid Loss: 0.0024
#
# ![Screenshot from 2022-09-01 11-33-24.png](data:image/png;base64,...)
